# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\house_price_regression_dataset.csv")

# %%
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
df.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
# 1            4272             3              3        2016  4.753014
# 2            3592             1              2        2016  3.634823
# 3             966             1              2        1977  2.730667
# 4            4926             2              1        1993  4.699073
#
#    Garage_Size  Neighborhood_Quality   House_Price
# 0            0                     5  2.623829e+05
# 1            1                     6  9.852609e+05
# 2            0                     9  7.779774e+05
# 3            1                     8  2.296989e+05
# 4            0                     8  1.041741e+06

# %%
df.tail()
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality    House_Price
# 995            2                    10  701493.997069
# 996            1                    10  683723.160704
# 997            0                     2  572024.023634
# 998            0                     7  964865.298639
# 999            2                     2  742599.253332

# %%
df.describe()
# Out:
#        Square_Footage  Num_Bedrooms  Num_Bathrooms   Year_Built     Lot_Size  \
# count     1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean      2815.422000      2.990000       1.973000  1986.550000     2.778087
# std       1255.514921      1.427564       0.820332    20.632916     1.297903
# min        503.000000      1.000000       1.000000  1950.000000     0.506058
# 25%       1749.500000      2.000000       1.000000  1969.000000     1.665946
# 50%       2862.500000      3.000000       2.000000  1986.000000     2.809740
# 75%       3849.500000      4.000000       3.000000  2004.250000     3.923317
# max       4999.000000      5.000000       3.000000  2022.000000     4.989303
#
#        Garage_Size  Neighborhood_Quality   House_Price
# count  1000.000000           1000.000000  1.000000e+03
# mean      1.022000              5.615000  6.188610e+05
# std       0.814973              2.887059  2.535681e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        1000 non-null   int64
#  1   Num_Bedrooms          1000 non-null   int64
#  2   Num_Bathrooms         1000 non-null   int64
#  3   Year_Built            1000 non-null   int64
#  4   Lot_Size              1000 non-null   float64
#  5   Garage_Size           1000 non-null   int64
#  6   Neighborhood_Quality  1000 non-null   int64
#  7   House_Price           1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
print(df.columns.tolist())
# Out:
# ['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built', 'Lot_Size', 'Garage_Size', 'Neighborhood_Quality', 'House_Price']

# %%
df.isnull().sum()
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built', 'Lot_Size', 'Garage_Size', 'Neighborhood_Quality', 'House_Price']

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and all values are non-null

# 1. Scatter Plot: Square Footage vs House Price
plt.figure(figsize=(8, 6), dpi=100)
plt.title("Square Footage vs House Price")
plt.xlabel("Square Footage")
plt.ylabel("House Price")
plt.scatter(df['Square_Footage'], df['House_Price'], alpha=0.6, color='skyblue')
plt.grid(True)
plt.show()

# %%
avg_price_by_bedroom = df.groupby('Num_Bedrooms')['House_Price'].mean()
plt.figure(figsize=(8, 6), dpi=100)
plt.title("Average House Price by Number of Bedrooms")
plt.xlabel("Number of Bedrooms")
plt.ylabel("Average House Price")
avg_price_by_bedroom.plot(kind='bar', color='orange')
plt.grid(axis='y')
plt.show()

# %%
neighborhood_counts = df['Neighborhood_Quality'].value_counts()
plt.figure(figsize=(8, 6), dpi=100)
plt.title("Neighborhood Quality Distribution")
plt.pie(neighborhood_counts, labels=neighborhood_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=100)
plt.title("Distribution of House Prices")
plt.xlabel("House Price")
plt.ylabel("Frequency")
plt.hist(df['House_Price'], bins=30, color='green', edgecolor='black')
plt.grid(True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        1000 non-null   int64
#  1   Num_Bedrooms          1000 non-null   int64
#  2   Num_Bathrooms         1000 non-null   int64
#  3   Year_Built            1000 non-null   int64
#  4   Lot_Size              1000 non-null   float64
#  5   Garage_Size           1000 non-null   int64
#  6   Neighborhood_Quality  1000 non-null   int64
#  7   House_Price           1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
x=df.drop('House_Price',axis=1)

y=df['House_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (800, 7)

# %%
x_test.shape
# Out:
# (200, 7)

# %%
y_train.shape
# Out:
# (800,)

# %%
y_test.shape
# Out:
# (200,)

# %%
#import StandardScaler
from sklearn.preprocessing import StandardScaler
#create the object/model
sc=StandardScaler()
#transform or scaling the value
x_train=sc.fit_transform(x_train)
x_train
x_test=sc.transform(x_test)
x_test
# Out:
# array([[ 0.9569591 ,  0.02199955, -1.19064416, ..., -0.52579887,
#         -0.01829438, -0.20465373],
#        [-0.40248034,  0.02199955, -1.19064416, ..., -1.09387796,
#         -0.01829438, -0.54788851],
#        [ 1.51287558, -1.38597173,  1.26113274, ..., -0.76374075,
#         -0.01829438,  0.82505058],
#        ...,
#        [ 1.33955105,  0.72598519,  0.03524429, ...,  0.48880234,
#         -1.23791995, -0.54788851],
#        [-0.76350656, -1.38597173, -1.19064416, ...,  1.38366418,
#          1.20133118,  0.82505058],
#        [ 0.30439622, -1.38597173, -1.19064416, ...,  0.88971283,
#          1.20133118, -1.57759282]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
result=lr.predict(x_test)

# %%
result
# Out:
# array([ 868687.10747904,  490337.89825447,  945667.12422538,
#        1033402.87599249,  776698.77390588,  732444.09335309,
#         995051.99156274,  885174.76924364,  796730.53817138,
#         931741.09209273,  759486.73376772,  645409.40410205,
#         217706.20688727, 1047436.52669429,  536985.283711  ,
#         187868.55343103,  456819.02346556,  357933.98497767,
#         743138.35721931,  362670.9479679 ,  775101.05248528,
#         478174.42921702,  680966.0634508 ,  889457.56001473,
#         447158.93387225,  396997.78641331,  454334.22026962,
#         442837.53540886,  187336.81096628,  491668.18070411,
#         279715.81740977,  895941.00057431,  783583.19778843,
#         352212.91737967,  479313.28465599,  766612.6601435 ,
#         474636.25109508,  572446.37288032,  303449.70619641,
#         154599.27036071,  304341.05092123,  299677.00775283,
#         508575.91105887,  309977.51725284, 1082131.76994764,
# ...

# %%
y_test
# Out:
# 521    9.010005e+05
# 737    4.945375e+05
# 740    9.494042e+05
# 660    1.040389e+06
# 411    7.940100e+05
#            ...
# 408    8.245296e+05
# 332    1.803936e+05
# 208    9.658167e+05
# 613    4.336642e+05
# 78     6.639050e+05
# Name: House_Price, Length: 200, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, root_mean_squared_error

# %%
mae=mean_absolute_error(y_test, result)
mse =mean_squared_error(y_test, result)
rmse= root_mean_squared_error(y_test,result)

print("MAE: ",mae)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MAE:  8174.583600006595
# MSE:  101434798.50563554
# RMSE:  10071.484424137067

# %%
train_score=lr.score(x_train,y_train)
print(train_score)
test_score=lr.score(x_test,y_test)
print(test_score)
# Out:
# 0.9985375946918145
# 0.9984263636823413

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
res=dt.predict(x_test)

# %%
res
# Out:
# array([ 844959.84123391,  501720.67572174,  923773.12935606,
#        1041740.8589249 ,  806645.0448681 ,  720883.65717106,
#         955158.90638745,  899849.51882009,  816939.58743084,
#         923122.11417869,  740286.55974695,  663727.54412406,
#         234762.82447901, 1037268.04342802,  525408.91551059,
#         214146.49100739,  506990.32475704,  405144.67006802,
#         742599.25333236,  372292.60339232,  804433.80932186,
#         501913.64710804,  688516.50466909,  891638.50869646,
#         432387.04102579,  370260.60316679,  510876.99909322,
#         357130.1202818 ,  198204.12830507,  440726.28481629,
#         250362.35906875,  934942.05713292,  738935.81944604,
#         341253.22077951,  454484.4215051 ,  772740.07072754,
#         475471.17666868,  621862.76541835,  267185.26764161,
#         158636.70310577,  308618.4072722 ,  266533.05392412,
#         497340.99811599,  288382.46046148, 1108236.83629137,
# ...

# %%
y_test
# Out:
# 521    9.010005e+05
# 737    4.945375e+05
# 740    9.494042e+05
# 660    1.040389e+06
# 411    7.940100e+05
#            ...
# 408    8.245296e+05
# 332    1.803936e+05
# 208    9.658167e+05
# 613    4.336642e+05
# 78     6.639050e+05
# Name: House_Price, Length: 200, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
mae=mean_absolute_error(y_test, res)
mse =mean_squared_error(y_test, res)
rmse= root_mean_squared_error(y_test,res)

print("MAE: ",mae)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MAE:  24398.476482494298
# MSE:  989706184.0179242
# RMSE:  31459.596056178536

# %%
train_score=dt.score(x_train,y_train)
print(train_score)

test_score=dt.score(x_test,y_test)
print(test_score)
# Out:
# 1.0
# 0.9846459241017228

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_result= rf.predict(x_test)

# %%
mae=mean_absolute_error(y_test, rf_result)
mse =mean_squared_error(y_test, rf_result)
rmse= root_mean_squared_error(y_test,rf_result)

print("MAE: ",mae)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MAE:  15954.92240234043
# MSE:  392449458.3290599
# RMSE:  19810.337158389302

# %%
#model score
train_score=rf.score(x_train,y_train)
print(train_score)

test_score=rf.score(x_test,y_test)
print(test_score)
# Out:
# 0.9989539450363214
# 0.9939116286563356

# %%
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
# visualization,model deployment

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
x_test.shape
# Out:
# (200, 7)

# %%
df.iloc[100]  # But your df has only, say, 50 rows.
# Out:
# Square_Footage             706.000000
# Num_Bedrooms                 3.000000
# Num_Bathrooms                3.000000
# Year_Built                1986.000000
# Lot_Size                     3.198971
# Garage_Size                  1.000000
# Neighborhood_Quality        10.000000
# House_Price             199414.942633
# Name: 100, dtype: float64

# %%
x_test[100]  # Already a NumPy array, this gives you the 101st row
# Out:
# array([ 1.13507602,  0.02199955,  1.26113274,  0.62979269, -0.67116846,
#        -0.01829438,  0.82505058])

# %%
y_test.iloc[100]
# Out:
# 917235.4105319374

# %%
#how we can predict
result=rf.predict([[1.13507602,  0.02199955,  1.26113274,  0.62979269, -0.67116846,
       -0.01829438,  0.82505058]])
print(result)
# Out:
# [896719.75304933]

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle

# %%
with open("House_Price.rf.model.pkl","wb")as file:
    pickle.dump(rf,file)

# %%
with open("sc.pkl","wb")as file:
    pickle.dump(sc,file)

# %%
with open("House_Price.rf.model.pkl","rb")as file:
    house_model=pickle.load(file)

# %%
with open("sc.pkl","rb")as file:
    sc_model=pickle.load(file)

# %%
x_train.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[229], line 1
# ----> 1 x_train.df.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'df'

# %%
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
def predict_house_price_features(
    Square_Footage=1500.0,
    Num_Bedrooms=3,
    Num_Bathrooms=2,
    Year_Built=2000,
    Lot_Size=0.5,
    Garage_Size=2,
    Neighborhood_Quality='Medium'  # Assume 'Low'=0, 'Medium'=1, 'High'=2
):
    lst = []

    # Numerical features
    lst.append(Square_Footage)
    lst.append(Num_Bedrooms)
    lst.append(Num_Bathrooms)
    lst.append(Year_Built)
    lst.append(Lot_Size)
    lst.append(Garage_Size)

    # Categorical encoding for Neighborhood_Quality
    quality_map = {'Low': 0, 'Medium': 1, 'High': 2}
    encoded_quality = quality_map.get(Neighborhood_Quality, 1)  # Default to 'Medium'
    lst.append(encoded_quality)

    return lst

# %%
features = predict_house_price_features(
    Square_Footage=2100.0,
    Num_Bedrooms=4,
    Num_Bathrooms=3,
    Year_Built=2015,
    Lot_Size=0.8,
    Garage_Size=2,
    Neighborhood_Quality='High'
)

# Scale and predict
scaled_features = sc.transform([features])
predicted_price = house_model.predict(scaled_features)
print("Predicted House Price:", predicted_price)
# Out:
# Predicted House Price: [468178.23518467]
# C:\Users\DELL\New folder\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
Square_Footage = float(input("Enter square footage: "))
Num_Bedrooms = int(input("Enter number of bedrooms: "))
Num_Bathrooms = int(input("Enter number of bathrooms: "))
Year_Built = int(input("Enter year built: "))
Lot_Size = float(input("Enter lot size (in acres): "))
Garage_Size = int(input("Enter garage size (number of cars): "))
Neighborhood_Quality = input("Enter neighborhood quality (Low/Medium/High): ")
print("💰 Predicted House Price:", predicted_price[0])
# Out:
# Enter square footage:  23
# Enter number of bedrooms:  45
# Enter number of bathrooms:  67
# Enter year built:  88
# Enter lot size (in acres):  90
# Enter garage size (number of cars):  3
# Enter neighborhood quality (Low/Medium/High):  34
# 💰 Predicted House Price: 468178.23518467374
